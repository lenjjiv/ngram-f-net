# %%
import importlib
import calculate_distances
importlib.reload(calculate_distances)
# Out:
# <module 'calculate_distances' from 'c:\\Users\\lenjjiv\\code-projects\\experiments\\n-gram-embedder\\calculate_distances.py'>

# %%
from calculate_distances import optimize_coulomb_energy

# Пример использования функции
points, energy = optimize_coulomb_energy(N=100, d=32, lr=0.05, n_iter=48, log_iter=4)
# Out:
# Iter    4 | Energy = 2516.9778
# Iter    8 | Energy = 2509.5156
# Iter   12 | Energy = 2505.7268
# Iter   16 | Energy = 2503.5349
# Iter   20 | Energy = 2502.1460
# Iter   24 | Energy = 2501.1785
# Iter   28 | Energy = 2500.4543
# Iter   32 | Energy = 2499.8691
# Iter   36 | Energy = 2499.3647
# Iter   40 | Energy = 2498.9294
# Iter   44 | Energy = 2498.5232
# Iter   48 | Energy = 2498.1611

# %%
from calculate_distances import calculate_distances

# Проверяем, что все точки находятся на сфере
calculate_distances(points)
# Out:
# Минимальное косинусное расстояние: 0.7326564906082844
# Среднее косинусное расстояние: 0.9999999967426005
# Дисперсия косинусного расстояния: 0.03137442008100376
# Максимальное косинусное расстояние: 1.6876473109076895
#
# Минимальное евклидово расстояние: 1.2105010917005563
# Среднее евклидово расстояние: 1.4035960356155992
# Дисперсия евклидово расстояния: 0.029918178853110367
# Максимальное евклидово расстояние: 1.8371975587187086
